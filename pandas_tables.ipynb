# %%
import json
from binance.client import Client
import pandas as pd

# %%
with open("credentials.json", "r") as f:
    creds = json.load(f)
client = Client(creds['API_KEY'], creds['SECRET_KEY'], tld='us')

# %%
tickers = client.get_ticker()

# %%
tickers
# Out:
# [{'symbol': 'BTCUSD',
#   'priceChange': '-852.6200',
#   'priceChangePercent': '-1.536',
#   'weightedAvgPrice': '54485.4689',
#   'prevClosePrice': '55525.4000',
#   'lastPrice': '54672.7800',
#   'lastQty': '0.00837000',
#   'bidPrice': '54663.3900',
#   'bidQty': '0.00000500',
#   'askPrice': '54663.4000',
#   'askQty': '0.25900000',
#   'openPrice': '55525.4000',
#   'highPrice': '56379.9700',
#   'lowPrice': '52600.0000',
#   'volume': '1720.35770200',
#   'quoteVolume': '93734496.1340',
#   'openTime': 1619014209574,
#   'closeTime': 1619100609574,
#   'firstId': 10861267,
#   'lastId': 10952425,
#   'count': 91159},
#  {'symbol': 'ETHUSD',
#   'priceChange': '185.4200',
#   'priceChangePercent': '7.778',
#   'weightedAvgPrice': '2438.6539',
#   'prevClosePrice': '2383.8700',
#   'lastPrice': '2569.4000',
#   'lastQty': '0.16947000',
#   'bidPrice': '2569.5700',
#   'bidQty': '1.06579000',
#   'askPrice': '2570.7500',
#   'askQty': '2.33469000',
#   'openPrice': '2383.9800',
#   'highPrice': '2600.0000',
#   'lowPrice': '2316.1800',
#   'volume': '44523.33795000',
#   'quoteVolume': '108577013.9571',
#   'openTime': 1619014211758,
#   'closeTime': 1619100611758,
#   'firstId': 4966647,
#   'lastId': 5078606,
#   'count': 111960},
#  {'symbol': 'XRPUSD',
#   'priceChange': '0.0000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.2970',
#   'prevClosePrice': '0.2970',
#   'lastPrice': '0.2970',
#   'lastQty': '2180.60000000',
#   'bidPrice': '0.0000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.0000',
#   'askQty': '0.00000000',
#   'openPrice': '0.2970',
#   'highPrice': '0.2970',
#   'lowPrice': '0.2970',
#   'volume': '2180.60000000',
#   'quoteVolume': '647.6382',
#   'openTime': 1618492909016,
#   'closeTime': 1618579309016,
#   'firstId': 1603396,
#   'lastId': 1603396,
#   'count': 1},
#  {'symbol': 'BCHUSD',
#   'priceChange': '-4.5800',
#   'priceChangePercent': '-0.485',
#   'weightedAvgPrice': '935.1071',
#   'prevClosePrice': '945.2900',
#   'lastPrice': '939.8800',
#   'lastQty': '1.33669000',
#   'bidPrice': '939.3200',
#   'bidQty': '0.84082000',
#   'askPrice': '940.7900',
#   'askQty': '0.50000000',
#   'openPrice': '944.4600',
#   'highPrice': '989.0600',
#   'lowPrice': '886.0000',
#   'volume': '4818.80953000',
#   'quoteVolume': '4506103.1347',
#   'openTime': 1619014211450,
#   'closeTime': 1619100611450,
#   'firstId': 1079253,
#   'lastId': 1091804,
#   'count': 12552},
#  {'symbol': 'LTCUSD',
#   'priceChange': '13.7900',
#   'priceChangePercent': '5.209',
#   'weightedAvgPrice': '268.9960',
#   'prevClosePrice': '264.3000',
#   'lastPrice': '278.5300',
#   'lastQty': '1.00000000',
#   'bidPrice': '278.1400',
#   'bidQty': '0.79003000',
#   'askPrice': '278.5400',
#   'askQty': '4.65926000',
#   'openPrice': '264.7400',
#   'highPrice': '286.1800',
#   'lowPrice': '251.2800',
#   'volume': '50527.80283000',
#   'quoteVolume': '13591774.6350',
#   'openTime': 1619014211105,
#   'closeTime': 1619100611105,
#   'firstId': 1669042,
#   'lastId': 1694084,
#   'count': 25043},
#  {'symbol': 'USDTUSD',
#   'priceChange': '0.0000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '1.0002',
#   'prevClosePrice': '1.0005',
#   'lastPrice': '1.0005',
#   'lastQty': '7953.21000000',
#   'bidPrice': '1.0004',
#   'bidQty': '1421.99000000',
#   'askPrice': '1.0005',
#   'askQty': '10273.53000000',
#   'openPrice': '1.0005',
#   'highPrice': '1.0009',
#   'lowPrice': '0.9995',
#   'volume': '97479707.65000000',
#   'quoteVolume': '97499225.0317',
#   'openTime': 1619014210010,
#   'closeTime': 1619100610010,
#   'firstId': 5305647,
#   'lastId': 5331685,
#   'count': 26039},
#  {'symbol': 'BTCUSDT',
#   'priceChange': '-861.76000000',
#   'priceChangePercent': '-1.553',
#   'weightedAvgPrice': '54367.23186083',
#   'prevClosePrice': '55492.24000000',
#   'lastPrice': '54621.84000000',
#   'lastQty': '0.01987000',
#   'bidPrice': '54614.63000000',
#   'bidQty': '0.10980600',
#   'askPrice': '54638.11000000',
#   'askQty': '0.01799200',
#   'openPrice': '55483.60000000',
#   'highPrice': '56344.57000000',
#   'lowPrice': '52588.04000000',
#   'volume': '795.66182700',
#   'quoteVolume': '43257931.03132352',
#   'openTime': 1619014211150,
#   'closeTime': 1619100611150,
#   'firstId': 3802453,
#   'lastId': 3840614,
#   'count': 38162},
#  {'symbol': 'ETHUSDT',
#   'priceChange': '185.87000000',
#   'priceChangePercent': '7.803',
#   'weightedAvgPrice': '2443.15828137',
#   'prevClosePrice': '2381.94000000',
#   'lastPrice': '2567.81000000',
#   'lastQty': '0.77816000',
#   'bidPrice': '2569.38000000',
#   'bidQty': '0.00394000',
#   'askPrice': '2569.70000000',
#   'askQty': '1.77360000',
#   'openPrice': '2381.94000000',
#   'highPrice': '2598.40000000',
#   'lowPrice': '2315.24000000',
#   'volume': '13616.46348000',
#   'quoteVolume': '33267175.51413590',
#   'openTime': 1619014211690,
#   'closeTime': 1619100611690,
#   'firstId': 1960225,
#   'lastId': 1991166,
#   'count': 30942},
#  {'symbol': 'XRPUSDT',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.29691000',
#   'prevClosePrice': '0.29691000',
#   'lastPrice': '0.29691000',
#   'lastQty': '1010.40000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.29691000',
#   'highPrice': '0.29691000',
#   'lowPrice': '0.29691000',
#   'volume': '1010.40000000',
#   'quoteVolume': '299.99786400',
#   'openTime': 1618492909016,
#   'closeTime': 1618579309016,
#   'firstId': 869258,
#   'lastId': 869258,
#   'count': 1},
#  {'symbol': 'BCHUSDT',
#   'priceChange': '-2.00000000',
#   'priceChangePercent': '-0.212',
#   'weightedAvgPrice': '934.31472069',
#   'prevClosePrice': '944.69000000',
#   'lastPrice': '941.02000000',
#   'lastQty': '0.76197000',
#   'bidPrice': '938.95000000',
#   'bidQty': '0.06578000',
#   'askPrice': '940.40000000',
#   'askQty': '0.06234000',
#   'openPrice': '943.02000000',
#   'highPrice': '988.35000000',
#   'lowPrice': '885.32000000',
#   'volume': '3950.16537000',
#   'quoteVolume': '3690697.65434140',
#   'openTime': 1619014210088,
#   'closeTime': 1619100610088,
#   'firstId': 787856,
#   'lastId': 795826,
#   'count': 7971},
#  {'symbol': 'LTCUSDT',
#   'priceChange': '14.09000000',
#   'priceChangePercent': '5.331',
#   'weightedAvgPrice': '268.39420640',
#   'prevClosePrice': '264.17000000',
#   'lastPrice': '278.40000000',
#   'lastQty': '2.41011000',
#   'bidPrice': '278.05000000',
#   'bidQty': '2.87337000',
#   'askPrice': '278.34000000',
#   'askQty': '3.57674000',
#   'openPrice': '264.31000000',
#   'highPrice': '285.95000000',
#   'lowPrice': '251.31000000',
#   'volume': '26148.96268000',
#   'quoteVolume': '7018230.08671140',
#   'openTime': 1619014207585,
#   'closeTime': 1619100607585,
#   'firstId': 1286112,
#   'lastId': 1302785,
#   'count': 16674},
#  {'symbol': 'BNBUSD',
#   'priceChange': '-12.9585',
#   'priceChangePercent': '-2.222',
#   'weightedAvgPrice': '559.8100',
#   'prevClosePrice': '583.3205',
#   'lastPrice': '570.1696',
#   'lastQty': '0.02000000',
#   'bidPrice': '570.0000',
#   'bidQty': '0.21000000',
#   'askPrice': '570.3624',
#   'askQty': '0.61000000',
#   'openPrice': '583.1281',
#   'highPrice': '589.4645',
#   'lowPrice': '532.0959',
#   'volume': '190062.23000000',
#   'quoteVolume': '106398735.9198',
#   'openTime': 1619014211173,
#   'closeTime': 1619100611173,
#   'firstId': 3919591,
#   'lastId': 4047581,
#   'count': 127991},
#  {'symbol': 'BNBUSDT',
#   'priceChange': '-12.49040000',
#   'priceChangePercent': '-2.144',
#   'weightedAvgPrice': '558.43883482',
#   'prevClosePrice': '582.71310000',
#   'lastPrice': '570.04800000',
#   'lastQty': '0.04000000',
#   'bidPrice': '569.57800000',
#   'bidQty': '19.97000000',
#   'askPrice': '570.04800000',
#   'askQty': '4.49000000',
#   'openPrice': '582.53840000',
#   'highPrice': '589.34010000',
#   'lowPrice': '531.55290000',
#   'volume': '47951.39000000',
#   'quoteVolume': '26777918.35949000',
#   'openTime': 1619014211640,
#   'closeTime': 1619100611640,
#   'firstId': 1391429,
#   'lastId': 1412080,
#   'count': 20652},
#  {'symbol': 'ETHBTC',
#   'priceChange': '0.00413100',
#   'priceChangePercent': '9.631',
#   'weightedAvgPrice': '0.04514077',
#   'prevClosePrice': '0.04286100',
#   'lastPrice': '0.04702500',
#   'lastQty': '0.02000000',
#   'bidPrice': '0.04702500',
#   'bidQty': '0.02600000',
#   'askPrice': '0.04703000',
#   'askQty': '0.00300000',
#   'openPrice': '0.04289400',
#   'highPrice': '0.04712600',
#   'lowPrice': '0.04273200',
#   'volume': '4012.22800000',
#   'quoteVolume': '181.11504399',
#   'openTime': 1619014211706,
#   'closeTime': 1619100611706,
#   'firstId': 881893,
#   'lastId': 889699,
#   'count': 7807},
#  {'symbol': 'XRPBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000864',
#   'prevClosePrice': '0.00000864',
#   'lastPrice': '0.00000864',
#   'lastQty': '938.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000864',
#   'highPrice': '0.00000864',
#   'lowPrice': '0.00000864',
#   'volume': '938.00000000',
#   'quoteVolume': '0.00810432',
#   'openTime': 1618492909016,
#   'closeTime': 1618579309016,
#   'firstId': 433801,
#   'lastId': 433801,
#   'count': 1},
#  {'symbol': 'BNBBTC',
#   'priceChange': '-0.00006410',
#   'priceChangePercent': '-0.610',
#   'weightedAvgPrice': '0.01025402',
#   'prevClosePrice': '0.01051060',
#   'lastPrice': '0.01044190',
#   'lastQty': '0.86000000',
#   'bidPrice': '0.01042370',
#   'bidQty': '0.73000000',
#   'askPrice': '0.01044000',
#   'askQty': '4.05000000',
#   'openPrice': '0.01050600',
#   'highPrice': '0.01051680',
#   'lowPrice': '0.00997140',
#   'volume': '20882.17000000',
#   'quoteVolume': '214.12617252',
#   'openTime': 1619014206208,
#   'closeTime': 1619100606208,
#   'firstId': 1037492,
#   'lastId': 1049015,
#   'count': 11524},
#  {'symbol': 'LTCBTC',
#   'priceChange': '0.00033100',
#   'priceChangePercent': '6.951',
#   'weightedAvgPrice': '0.00495203',
#   'prevClosePrice': '0.00476100',
#   'lastPrice': '0.00509300',
#   'lastQty': '2.28000000',
#   'bidPrice': '0.00509000',
#   'bidQty': '2.83000000',
#   'askPrice': '0.00509300',
#   'askQty': '23.08000000',
#   'openPrice': '0.00476200',
#   'highPrice': '0.00527700',
#   'lowPrice': '0.00472400',
#   'volume': '9907.38000000',
#   'quoteVolume': '49.06160839',
#   'openTime': 1619014210371,
#   'closeTime': 1619100610371,
#   'firstId': 521437,
#   'lastId': 526659,
#   'count': 5223},
#  {'symbol': 'BCHBTC',
#   'priceChange': '0.00016200',
#   'priceChangePercent': '0.952',
#   'weightedAvgPrice': '0.01719070',
#   'prevClosePrice': '0.01701200',
#   'lastPrice': '0.01718200',
#   'lastQty': '0.16900000',
#   'bidPrice': '0.01718300',
#   'bidQty': '0.88600000',
#   'askPrice': '0.01721000',
#   'askQty': '0.98600000',
#   'openPrice': '0.01702000',
#   'highPrice': '0.01781000',
#   'lowPrice': '0.01660200',
#   'volume': '1679.73500000',
#   'quoteVolume': '28.87581999',
#   'openTime': 1619014211341,
#   'closeTime': 1619100611341,
#   'firstId': 327799,
#   'lastId': 330792,
#   'count': 2994},
#  {'symbol': 'ADAUSD',
#   'priceChange': '-0.0180',
#   'priceChangePercent': '-1.444',
#   'weightedAvgPrice': '1.2200',
#   'prevClosePrice': '1.2459',
#   'lastPrice': '1.2287',
#   'lastQty': '191.50000000',
#   'bidPrice': '1.2274',
#   'bidQty': '13543.50000000',
#   'askPrice': '1.2288',
#   'askQty': '11010.80000000',
#   'openPrice': '1.2467',
#   'highPrice': '1.2715',
#   'lowPrice': '1.1800',
#   'volume': '32853935.30000000',
#   'quoteVolume': '40082661.0004',
#   'openTime': 1619014211401,
#   'closeTime': 1619100611401,
#   'firstId': 4853920,
#   'lastId': 4887230,
#   'count': 33311},
#  {'symbol': 'BATUSD',
#   'priceChange': '-0.0281',
#   'priceChangePercent': '-2.243',
#   'weightedAvgPrice': '1.2297',
#   'prevClosePrice': '1.2524',
#   'lastPrice': '1.2246',
#   'lastQty': '10.00000000',
#   'bidPrice': '1.2230',
#   'bidQty': '1632.60000000',
#   'askPrice': '1.2262',
#   'askQty': '1632.36000000',
#   'openPrice': '1.2527',
#   'highPrice': '1.2985',
#   'lowPrice': '1.1608',
#   'volume': '1427969.72000000',
#   'quoteVolume': '1756037.0947',
#   'openTime': 1619014207612,
#   'closeTime': 1619100607612,
#   'firstId': 599149,
#   'lastId': 602883,
#   'count': 3735},
#  {'symbol': 'ETCUSD',
#   'priceChange': '4.5933',
#   'priceChangePercent': '13.924',
#   'weightedAvgPrice': '35.5583',
#   'prevClosePrice': '32.9500',
#   'lastPrice': '37.5807',
#   'lastQty': '0.41000000',
#   'bidPrice': '37.4608',
#   'bidQty': '8.01000000',
#   'askPrice': '37.5945',
#   'askQty': '7.98000000',
#   'openPrice': '32.9874',
#   'highPrice': '39.5712',
#   'lowPrice': '31.5551',
#   'volume': '85247.78000000',
#   'quoteVolume': '3031270.1193',
#   'openTime': 1619014211581,
#   'closeTime': 1619100611581,
#   'firstId': 556165,
#   'lastId': 567466,
#   'count': 11302},
#  {'symbol': 'XLMUSD',
#   'priceChange': '-0.0119',
#   'priceChangePercent': '-2.356',
#   'weightedAvgPrice': '0.4971',
#   'prevClosePrice': '0.5059',
#   'lastPrice': '0.4931',
#   'lastQty': '1359.00000000',
#   'bidPrice': '0.4928',
#   'bidQty': '5743.20000000',
#   'askPrice': '0.4934',
#   'askQty': '729.00000000',
#   'openPrice': '0.5050',
#   'highPrice': '0.5170',
#   'lowPrice': '0.4745',
#   'volume': '15997839.40000000',
#   'quoteVolume': '7952232.6781',
#   'openTime': 1619014211682,
#   'closeTime': 1619100611682,
#   'firstId': 1563339,
#   'lastId': 1574537,
#   'count': 11199},
#  {'symbol': 'ZRXUSD',
#   'priceChange': '-0.0226',
#   'priceChangePercent': '-1.325',
#   'weightedAvgPrice': '1.6847',
#   'prevClosePrice': '1.7072',
#   'lastPrice': '1.6837',
#   'lastQty': '11.76000000',
#   'bidPrice': '1.6814',
#   'bidQty': '890.44000000',
#   'askPrice': '1.6861',
#   'askQty': '107.21000000',
#   'openPrice': '1.7063',
#   'highPrice': '1.8076',
#   'lowPrice': '1.5722',
#   'volume': '640438.83000000',
#   'quoteVolume': '1078957.7608',
#   'openTime': 1619014211164,
#   'closeTime': 1619100611164,
#   'firstId': 660324,
#   'lastId': 664006,
#   'count': 3683},
#  {'symbol': 'ADAUSDT',
#   'priceChange': '-0.01578000',
#   'priceChangePercent': '-1.268',
#   'weightedAvgPrice': '1.22004599',
#   'prevClosePrice': '1.24369000',
#   'lastPrice': '1.22827000',
#   'lastQty': '466.30000000',
#   'bidPrice': '1.22675000',
#   'bidQty': '2442.20000000',
#   'askPrice': '1.22831000',
#   'askQty': '1273.80000000',
#   'openPrice': '1.24405000',
#   'highPrice': '1.27054000',
#   'lowPrice': '1.18018000',
#   'volume': '8019688.70000000',
#   'quoteVolume': '9784389.04883800',
#   'openTime': 1619014211181,
#   'closeTime': 1619100611181,
#   'firstId': 1417850,
#   'lastId': 1425746,
#   'count': 7897},
#  {'symbol': 'BATUSDT',
#   'priceChange': '-0.02480000',
#   'priceChangePercent': '-1.993',
#   'weightedAvgPrice': '1.22750335',
#   'prevClosePrice': '1.25180000',
#   'lastPrice': '1.21980000',
#   'lastQty': '464.75000000',
#   'bidPrice': '1.22260000',
#   'bidQty': '1632.60000000',
#   'askPrice': '1.22580000',
#   'askQty': '17.40000000',
#   'openPrice': '1.24460000',
#   'highPrice': '1.29400000',
#   'lowPrice': '1.16570000',
#   'volume': '678289.64000000',
#   'quoteVolume': '832602.80519400',
#   'openTime': 1619014211387,
#   'closeTime': 1619100611387,
#   'firstId': 402040,
#   'lastId': 403713,
#   'count': 1674},
#  {'symbol': 'ETCUSDT',
#   'priceChange': '4.59600000',
#   'priceChangePercent': '13.927',
#   'weightedAvgPrice': '34.91376697',
#   'prevClosePrice': '33.04080000',
#   'lastPrice': '37.59550000',
#   'lastQty': '2.13000000',
#   'bidPrice': '37.50770000',
#   'bidQty': '21.39000000',
#   'askPrice': '37.57780000',
#   'askQty': '24.09000000',
#   'openPrice': '32.99950000',
#   'highPrice': '39.47620000',
#   'lowPrice': '31.59730000',
#   'volume': '156130.71000000',
#   'quoteVolume': '5451111.22504900',
#   'openTime': 1619014211417,
#   'closeTime': 1619100611417,
#   'firstId': 513766,
#   'lastId': 525436,
#   'count': 11671},
#  {'symbol': 'XLMUSDT',
#   'priceChange': '-0.01115000',
#   'priceChangePercent': '-2.211',
#   'weightedAvgPrice': '0.49484746',
#   'prevClosePrice': '0.50544000',
#   'lastPrice': '0.49322000',
#   'lastQty': '1248.60000000',
#   'bidPrice': '0.49255000',
#   'bidQty': '609.10000000',
#   'askPrice': '0.49352000',
#   'askQty': '4055.80000000',
#   'openPrice': '0.50437000',
#   'highPrice': '0.51650000',
#   'lowPrice': '0.47448000',
#   'volume': '3685185.80000000',
#   'quoteVolume': '1823604.85111900',
#   'openTime': 1619014211741,
#   'closeTime': 1619100611741,
#   'firstId': 895504,
#   'lastId': 898855,
#   'count': 3352},
#  {'symbol': 'ZRXUSDT',
#   'priceChange': '-0.03010000',
#   'priceChangePercent': '-1.764',
#   'weightedAvgPrice': '1.69772250',
#   'prevClosePrice': '1.70630000',
#   'lastPrice': '1.67580000',
#   'lastQty': '287.54000000',
#   'bidPrice': '1.68030000',
#   'bidQty': '891.05000000',
#   'askPrice': '1.68580000',
#   'askQty': '1086.01000000',
#   'openPrice': '1.70590000',
#   'highPrice': '1.80850000',
#   'lowPrice': '1.57030000',
#   'volume': '276468.66000000',
#   'quoteVolume': '469367.06408300',
#   'openTime': 1619014208619,
#   'closeTime': 1619100608619,
#   'firstId': 383019,
#   'lastId': 384882,
#   'count': 1864},
#  {'symbol': 'LINKUSD',
#   'priceChange': '2.0585',
#   'priceChangePercent': '5.475',
#   'weightedAvgPrice': '37.3211',
#   'prevClosePrice': '37.5547',
#   'lastPrice': '39.6555',
#   'lastQty': '2.69000000',
#   'bidPrice': '39.6555',
#   'bidQty': '0.77000000',
#   'askPrice': '39.6751',
#   'askQty': '50.48000000',
#   'openPrice': '37.5970',
#   'highPrice': '39.7000',
#   'lowPrice': '35.4366',
#   'volume': '225470.44000000',
#   'quoteVolume': '8414815.6947',
#   'openTime': 1619014211748,
#   'closeTime': 1619100611748,
#   'firstId': 2105630,
#   'lastId': 2118896,
#   'count': 13267},
#  {'symbol': 'RVNUSD',
#   'priceChange': '-0.0077',
#   'priceChangePercent': '-4.245',
#   'weightedAvgPrice': '0.1762',
#   'prevClosePrice': '0.1814',
#   'lastPrice': '0.1737',
#   'lastQty': '3288.00000000',
#   'bidPrice': '0.1735',
#   'bidQty': '25789.30000000',
#   'askPrice': '0.1737',
#   'askQty': '7446.00000000',
#   'openPrice': '0.1814',
#   'highPrice': '0.1877',
#   'lowPrice': '0.1680',
#   'volume': '14021688.10000000',
#   'quoteVolume': '2471113.6352',
#   'openTime': 1619014209718,
#   'closeTime': 1619100609718,
#   'firstId': 1159087,
#   'lastId': 1165251,
#   'count': 6165},
#  {'symbol': 'DASHUSD',
#   'priceChange': '-5.4800',
#   'priceChangePercent': '-1.766',
#   'weightedAvgPrice': '304.0816',
#   'prevClosePrice': '310.6800',
#   'lastPrice': '304.8400',
#   'lastQty': '0.48331000',
#   'bidPrice': '304.3800',
#   'bidQty': '0.98561000',
#   'askPrice': '304.9400',
#   'askQty': '0.03982000',
#   'openPrice': '310.3200',
#   'highPrice': '325.0000',
#   'lowPrice': '287.8600',
#   'volume': '3813.32775000',
#   'quoteVolume': '1159562.6464',
#   'openTime': 1619014207523,
#   'closeTime': 1619100607523,
#   'firstId': 411626,
#   'lastId': 415256,
#   'count': 3631},
#  {'symbol': 'ZECUSD',
#   'priceChange': '1.2500',
#   'priceChangePercent': '0.519',
#   'weightedAvgPrice': '242.2777',
#   'prevClosePrice': '241.4200',
#   'lastPrice': '242.0600',
#   'lastQty': '0.24532000',
#   'bidPrice': '242.7500',
#   'bidQty': '3.00000000',
#   'askPrice': '243.2800',
#   'askQty': '11.70743000',
#   'openPrice': '240.8100',
#   'highPrice': '255.9100',
#   'lowPrice': '231.6800',
#   'volume': '3902.63583000',
#   'quoteVolume': '945521.8193',
#   'openTime': 1619014211200,
#   'closeTime': 1619100611200,
#   'firstId': 322619,
#   'lastId': 325586,
#   'count': 2968},
#  {'symbol': 'ALGOUSD',
#   'priceChange': '0.0330',
#   'priceChangePercent': '2.638',
#   'weightedAvgPrice': '1.2722',
#   'prevClosePrice': '1.2490',
#   'lastPrice': '1.2840',
#   'lastQty': '1552.07300000',
#   'bidPrice': '1.2820',
#   'bidQty': '900.00000000',
#   'askPrice': '1.2840',
#   'askQty': '975.09200000',
#   'openPrice': '1.2510',
#   'highPrice': '1.3450',
#   'lowPrice': '1.1930',
#   'volume': '5824894.08100000',
#   'quoteVolume': '7410409.7036',
#   'openTime': 1619014211696,
#   'closeTime': 1619100611696,
#   'firstId': 1167246,
#   'lastId': 1181343,
#   'count': 14098},
#  {'symbol': 'IOTAUSD',
#   'priceChange': '-0.0415',
#   'priceChangePercent': '-1.913',
#   'weightedAvgPrice': '2.0994',
#   'prevClosePrice': '2.1711',
#   'lastPrice': '2.1284',
#   'lastQty': '746.54000000',
#   'bidPrice': '2.1192',
#   'bidQty': '623.23000000',
#   'askPrice': '2.1285',
#   'askQty': '42.05000000',
#   'openPrice': '2.1699',
#   'highPrice': '2.2837',
#   'lowPrice': '1.9801',
#   'volume': '1783073.58000000',
#   'quoteVolume': '3743457.6552',
#   'openTime': 1619014210826,
#   'closeTime': 1619100610826,
#   'firstId': 573764,
#   'lastId': 580836,
#   'count': 7073},
#  {'symbol': 'BUSDUSD',
#   'priceChange': '0.0000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.9997',
#   'prevClosePrice': '1.0000',
#   'lastPrice': '1.0000',
#   'lastQty': '203.13000000',
#   'bidPrice': '0.9999',
#   'bidQty': '9009.89000000',
#   'askPrice': '1.0000',
#   'askQty': '66030.00000000',
#   'openPrice': '1.0000',
#   'highPrice': '1.0003',
#   'lowPrice': '0.9990',
#   'volume': '5893608.21000000',
#   'quoteVolume': '5891759.2871',
#   'openTime': 1619014202986,
#   'closeTime': 1619100602986,
#   'firstId': 655544,
#   'lastId': 658268,
#   'count': 2725},
#  {'symbol': 'BTCBUSD',
#   'priceChange': '-653.32000000',
#   'priceChangePercent': '-1.181',
#   'weightedAvgPrice': '54307.73846460',
#   'prevClosePrice': '55511.84000000',
#   'lastPrice': '54671.68000000',
#   'lastQty': '0.00548700',
#   'bidPrice': '54640.69000000',
#   'bidQty': '0.06000000',
#   'askPrice': '54679.96000000',
#   'askQty': '0.05489300',
#   'openPrice': '55325.00000000',
#   'highPrice': '56340.58000000',
#   'lowPrice': '52592.03000000',
#   'volume': '60.54280400',
#   'quoteVolume': '3287942.76554554',
#   'openTime': 1619014211435,
#   'closeTime': 1619100611435,
#   'firstId': 588975,
#   'lastId': 591303,
#   'count': 2329},
#  {'symbol': 'DOGEUSDT',
#   'priceChange': '-0.03089090',
#   'priceChangePercent': '-9.859',
#   'weightedAvgPrice': '0.29110943',
#   'prevClosePrice': '0.31313800',
#   'lastPrice': '0.28243300',
#   'lastQty': '500.00000000',
#   'bidPrice': '0.28214210',
#   'bidQty': '17698.00000000',
#   'askPrice': '0.28264260',
#   'askQty': '17698.00000000',
#   'openPrice': '0.31332390',
#   'highPrice': '0.33287210',
#   'lowPrice': '0.25716840',
#   'volume': '115758007.00000000',
#   'quoteVolume': '33698247.13507790',
#   'openTime': 1619014211380,
#   'closeTime': 1619100611380,
#   'firstId': 1796839,
#   'lastId': 1834426,
#   'count': 37588},
#  {'symbol': 'WAVESUSD',
#   'priceChange': '-1.0033',
#   'priceChangePercent': '-6.689',
#   'weightedAvgPrice': '14.8435',
#   'prevClosePrice': '14.9350',
#   'lastPrice': '13.9950',
#   'lastQty': '3.68000000',
#   'bidPrice': '14.0656',
#   'bidQty': '39.98000000',
#   'askPrice': '14.0790',
#   'askQty': '11.38000000',
#   'openPrice': '14.9983',
#   'highPrice': '16.0000',
#   'lowPrice': '13.5652',
#   'volume': '80872.67000000',
#   'quoteVolume': '1200432.8090',
#   'openTime': 1619014208543,
#   'closeTime': 1619100608543,
#   'firstId': 326765,
#   'lastId': 331532,
#   'count': 4768},
#  {'symbol': 'ATOMUSDT',
#   'priceChange': '0.54800000',
#   'priceChangePercent': '2.706',
#   'weightedAvgPrice': '20.16385315',
#   'prevClosePrice': '20.26200000',
#   'lastPrice': '20.80000000',
#   'lastQty': '18.17300000',
#   'bidPrice': '20.84700000',
#   'bidQty': '47.87100000',
#   'askPrice': '20.91900000',
#   'askQty': '31.70000000',
#   'openPrice': '20.25200000',
#   'highPrice': '21.30700000',
#   'lowPrice': '19.07700000',
#   'volume': '58559.06600000',
#   'quoteVolume': '1180776.40727900',
#   'openTime': 1619014208653,
#   'closeTime': 1619100608653,
#   'firstId': 461262,
#   'lastId': 464601,
#   'count': 3340},
#  {'symbol': 'ATOMUSD',
#   'priceChange': '0.5720',
#   'priceChangePercent': '2.817',
#   'weightedAvgPrice': '20.2509',
#   'prevClosePrice': '20.3040',
#   'lastPrice': '20.8760',
#   'lastQty': '2.36700000',
#   'bidPrice': '20.8470',
#   'bidQty': '14.15500000',
#   'askPrice': '20.8880',
#   'askQty': '2.39700000',
#   'openPrice': '20.3040',
#   'highPrice': '21.3300',
#   'lowPrice': '19.1000',
#   'volume': '125412.03100000',
#   'quoteVolume': '2539711.5262',
#   'openTime': 1619014204029,
#   'closeTime': 1619100604029,
#   'firstId': 789834,
#   'lastId': 797436,
#   'count': 7603},
#  {'symbol': 'NEOUSDT',
#   'priceChange': '-1.38600000',
#   'priceChangePercent': '-1.361',
#   'weightedAvgPrice': '98.12124616',
#   'prevClosePrice': '101.98700000',
#   'lastPrice': '100.41500000',
#   'lastQty': '8.30500000',
#   'bidPrice': '99.92500000',
#   'bidQty': '2.00200000',
#   'askPrice': '100.24200000',
#   'askQty': '150.00000000',
#   'openPrice': '101.80100000',
#   'highPrice': '105.55600000',
#   'lowPrice': '91.06800000',
#   'volume': '25743.87800000',
#   'quoteVolume': '2526021.39040000',
#   'openTime': 1619014211392,
#   'closeTime': 1619100611392,
#   'firstId': 504784,
#   'lastId': 509808,
#   'count': 5025},
#  {'symbol': 'NEOUSD',
#   'priceChange': '-1.8940',
#   'priceChangePercent': '-1.854',
#   'weightedAvgPrice': '97.6863',
#   'prevClosePrice': '102.2510',
#   'lastPrice': '100.2580',
#   'lastQty': '10.68200000',
#   'bidPrice': '99.9500',
#   'bidQty': '150.00000000',
#   'askPrice': '100.3660',
#   'askQty': '150.00000000',
#   'openPrice': '102.1520',
#   'highPrice': '105.5500',
#   'lowPrice': '90.8570',
#   'volume': '42669.80900000',
#   'quoteVolume': '4168255.0645',
#   'openTime': 1619014211555,
#   'closeTime': 1619100611555,
#   'firstId': 468306,
#   'lastId': 474857,
#   'count': 6552},
#  {'symbol': 'VETUSDT',
#   'priceChange': '-0.01411400',
#   'priceChangePercent': '-5.924',
#   'weightedAvgPrice': '0.22760411',
#   'prevClosePrice': '0.23800900',
#   'lastPrice': '0.22415000',
#   'lastQty': '4481.00000000',
#   'bidPrice': '0.22368700',
#   'bidQty': '894.00000000',
#   'askPrice': '0.22415400',
#   'askQty': '23803.00000000',
#   'openPrice': '0.23826400',
#   'highPrice': '0.24650500',
#   'lowPrice': '0.20788100',
#   'volume': '103845600.00000000',
#   'quoteVolume': '23635685.66337400',
#   'openTime': 1619014211321,
#   'closeTime': 1619100611321,
#   'firstId': 1423408,
#   'lastId': 1438389,
#   'count': 14982},
#  {'symbol': 'QTUMUSDT',
#   'priceChange': '-0.99400000',
#   'priceChangePercent': '-6.006',
#   'weightedAvgPrice': '15.52629417',
#   'prevClosePrice': '16.55000000',
#   'lastPrice': '15.55600000',
#   'lastQty': '40.12700000',
#   'bidPrice': '15.55900000',
#   'bidQty': '37.38600000',
#   'askPrice': '15.59100000',
#   'askQty': '37.25000000',
#   'openPrice': '16.55000000',
#   'highPrice': '16.99400000',
#   'lowPrice': '14.66500000',
#   'volume': '70292.60100000',
#   'quoteVolume': '1091383.60141800',
#   'openTime': 1619014211555,
#   'closeTime': 1619100611555,
#   'firstId': 265933,
#   'lastId': 268579,
#   'count': 2647},
#  {'symbol': 'QTUMUSD',
#   'priceChange': '-1.0500',
#   'priceChangePercent': '-6.328',
#   'weightedAvgPrice': '15.7700',
#   'prevClosePrice': '16.5970',
#   'lastPrice': '15.5440',
#   'lastQty': '118.08900000',
#   'bidPrice': '15.5610',
#   'bidQty': '134.20000000',
#   'askPrice': '15.6020',
#   'askQty': '140.37700000',
#   'openPrice': '16.5940',
#   'highPrice': '17.0260',
#   'lowPrice': '14.6630',
#   'volume': '75943.08300000',
#   'quoteVolume': '1197625.8048',
#   'openTime': 1619014211578,
#   'closeTime': 1619100611578,
#   'firstId': 443558,
#   'lastId': 446693,
#   'count': 3136},
#  {'symbol': 'NANOUSD',
#   'priceChange': '-0.5400',
#   'priceChangePercent': '-5.263',
#   'weightedAvgPrice': '10.2753',
#   'prevClosePrice': '10.2600',
#   'lastPrice': '9.7200',
#   'lastQty': '0.07000000',
#   'bidPrice': '9.6400',
#   'bidQty': '39.71000000',
#   'askPrice': '9.7200',
#   'askQty': '0.62000000',
#   'openPrice': '10.2600',
#   'highPrice': '11.5000',
#   'lowPrice': '9.0500',
#   'volume': '433681.48000000',
#   'quoteVolume': '4456202.3173',
#   'openTime': 1619014208450,
#   'closeTime': 1619100608450,
#   'firstId': 624962,
#   'lastId': 644366,
#   'count': 19405},
#  {'symbol': 'ICXUSD',
#   'priceChange': '-0.0507',
#   'priceChangePercent': '-2.267',
#   'weightedAvgPrice': '2.1811',
#   'prevClosePrice': '2.2369',
#   'lastPrice': '2.1856',
#   'lastQty': '129.27000000',
#   'bidPrice': '2.1835',
#   'bidQty': '914.46000000',
#   'askPrice': '2.1874',
#   'askQty': '20.68000000',
#   'openPrice': '2.2363',
#   'highPrice': '2.3490',
#   'lowPrice': '2.0346',
#   'volume': '699874.12000000',
#   'quoteVolume': '1526504.6227',
#   'openTime': 1619014209410,
#   'closeTime': 1619100609410,
#   'firstId': 553726,
#   'lastId': 557125,
#   'count': 3400},
#  {'symbol': 'ENJUSD',
#   'priceChange': '-0.1530',
#   'priceChangePercent': '-5.762',
#   'weightedAvgPrice': '2.5638',
#   'prevClosePrice': '2.6523',
#   'lastPrice': '2.5024',
#   'lastQty': '467.80000000',
#   'bidPrice': '2.4961',
#   'bidQty': '530.20000000',
#   'askPrice': '2.5024',
#   'askQty': '1435.00000000',
#   'openPrice': '2.6554',
#   'highPrice': '2.7969',
#   'lowPrice': '2.3767',
#   'volume': '3782839.10000000',
#   'quoteVolume': '9698500.1893',
#   'openTime': 1619014211692,
#   'closeTime': 1619100611692,
#   'firstId': 1295586,
#   'lastId': 1305914,
#   'count': 10329},
#  {'symbol': 'ONTUSD',
#   'priceChange': '-0.0992',
#   'priceChangePercent': '-4.971',
#   'weightedAvgPrice': '1.9093',
#   'prevClosePrice': '1.9992',
#   'lastPrice': '1.8963',
#   'lastQty': '5.80000000',
#   'bidPrice': '1.8958',
#   'bidQty': '250.00000000',
#   'askPrice': '1.8978',
#   'askQty': '11.32000000',
#   'openPrice': '1.9955',
#   'highPrice': '2.0543',
#   'lowPrice': '1.8150',
#   'volume': '459847.13000000',
#   'quoteVolume': '878004.4271',
#   'openTime': 1619014207617,
#   'closeTime': 1619100607617,
#   'firstId': 365055,
#   'lastId': 368867,
#   'count': 3813},
#  {'symbol': 'ONTUSDT',
#   'priceChange': '-0.09520000',
#   'priceChangePercent': '-4.785',
#   'weightedAvgPrice': '1.90998175',
#   'prevClosePrice': '2.00970000',
#   'lastPrice': '1.89420000',
#   'lastQty': '6.23000000',
#   'bidPrice': '1.89540000',
#   'bidQty': '451.22000000',
#   'askPrice': '1.89780000',
#   'askQty': '127.43000000',
#   'openPrice': '1.98940000',
#   'highPrice': '2.05740000',
#   'lowPrice': '1.80860000',
#   'volume': '801340.06000000',
#   'quoteVolume': '1530544.89263900',
#   'openTime': 1619014209795,
#   'closeTime': 1619100609795,
#   'firstId': 354374,
#   'lastId': 360696,
#   'count': 6323},
#  {'symbol': 'ZILUSD',
#   'priceChange': '-0.0058',
#   'priceChangePercent': '-3.137',
#   'weightedAvgPrice': '0.1785',
#   'prevClosePrice': '0.1849',
#   'lastPrice': '0.1791',
#   'lastQty': '252.60000000',
#   'bidPrice': '0.1787',
#   'bidQty': '12560.60000000',
#   'askPrice': '0.1794',
#   'askQty': '6790.70000000',
#   'openPrice': '0.1849',
#   'highPrice': '0.1915',
#   'lowPrice': '0.1703',
#   'volume': '22288583.00000000',
#   'quoteVolume': '3978202.6691',
#   'openTime': 1619014207440,
#   'closeTime': 1619100607440,
#   'firstId': 1164742,
#   'lastId': 1171325,
#   'count': 6584},
#  {'symbol': 'ZILBUSD',
#   'priceChange': '-0.00388000',
#   'priceChangePercent': '-2.123',
#   'weightedAvgPrice': '0.17735390',
#   'prevClosePrice': '0.18481000',
#   'lastPrice': '0.17885000',
#   'lastQty': '8358.10000000',
#   'bidPrice': '0.17892000',
#   'bidQty': '5583.50000000',
#   'askPrice': '0.17948000',
#   'askQty': '5576.90000000',
#   'openPrice': '0.18273000',
#   'highPrice': '0.19099000',
#   'lowPrice': '0.17007000',
#   'volume': '2101715.80000000',
#   'quoteVolume': '372747.49019300',
#   'openTime': 1619014208773,
#   'closeTime': 1619100608773,
#   'firstId': 170528,
#   'lastId': 170849,
#   'count': 322},
#  {'symbol': 'VETUSD',
#   'priceChange': '-0.0144',
#   'priceChangePercent': '-6.030',
#   'weightedAvgPrice': '0.2277',
#   'prevClosePrice': '0.2388',
#   'lastPrice': '0.2244',
#   'lastQty': '483.00000000',
#   'bidPrice': '0.2238',
#   'bidQty': '85972.00000000',
#   'askPrice': '0.2242',
#   'askQty': '1338.00000000',
#   'openPrice': '0.2388',
#   'highPrice': '0.2453',
#   'lowPrice': '0.2075',
#   'volume': '306854194.00000000',
#   'quoteVolume': '69867142.2454',
#   'openTime': 1619014210464,
#   'closeTime': 1619100610464,
#   'firstId': 3590568,
#   'lastId': 3650079,
#   'count': 59512},
#  {'symbol': 'BNBBUSD',
#   'priceChange': '-12.65170000',
#   'priceChangePercent': '-2.174',
#   'weightedAvgPrice': '556.68164343',
#   'prevClosePrice': '582.48750000',
#   'lastPrice': '569.25310000',
#   'lastQty': '0.53000000',
#   'bidPrice': '569.96740000',
#   'bidQty': '4.21000000',
#   'askPrice': '570.48960000',
#   'askQty': '3.91000000',
#   'openPrice': '581.90480000',
#   'highPrice': '589.28520000',
#   'lowPrice': '532.61650000',
#   'volume': '13568.89000000',
#   'quoteVolume': '7553551.98476800',
#   'openTime': 1619014208247,
#   'closeTime': 1619100608247,
#   'firstId': 309911,
#   'lastId': 315725,
#   'count': 5815},
#  {'symbol': 'XRPBUSD',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.30138000',
#   'prevClosePrice': '0.30138000',
#   'lastPrice': '0.30138000',
#   'lastQty': '680.70000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.30138000',
#   'highPrice': '0.30138000',
#   'lowPrice': '0.30138000',
#   'volume': '680.70000000',
#   'quoteVolume': '205.14936600',
#   'openTime': 1618492909016,
#   'closeTime': 1618579309016,
#   'firstId': 86052,
#   'lastId': 86052,
#   'count': 1},
#  {'symbol': 'ETHBUSD',
#   'priceChange': '181.15000000',
#   'priceChangePercent': '7.611',
#   'weightedAvgPrice': '2447.31582187',
#   'prevClosePrice': '2383.70000000',
#   'lastPrice': '2561.22000000',
#   'lastQty': '0.03720000',
#   'bidPrice': '2567.88000000',
#   'bidQty': '1.00000000',
#   'askPrice': '2572.08000000',
#   'askQty': '0.26207000',
#   'openPrice': '2380.07000000',
#   'highPrice': '2594.12000000',
#   'lowPrice': '2321.40000000',
#   'volume': '2474.96936000',
#   'quoteVolume': '6057031.67337380',
#   'openTime': 1619014211748,
#   'closeTime': 1619100611748,
#   'firstId': 178037,
#   'lastId': 184542,
#   'count': 6506},
#  {'symbol': 'ALGOBUSD',
#   'priceChange': '0.03440000',
#   'priceChangePercent': '2.768',
#   'weightedAvgPrice': '1.27447240',
#   'prevClosePrice': '1.24840000',
#   'lastPrice': '1.27700000',
#   'lastQty': '254.54000000',
#   'bidPrice': '1.28060000',
#   'bidQty': '1559.29000000',
#   'askPrice': '1.28400000',
#   'askQty': '1559.23000000',
#   'openPrice': '1.24260000',
#   'highPrice': '1.34500000',
#   'lowPrice': '1.19500000',
#   'volume': '523512.70000000',
#   'quoteVolume': '667202.48501000',
#   'openTime': 1619014211031,
#   'closeTime': 1619100611031,
#   'firstId': 144317,
#   'lastId': 145457,
#   'count': 1141},
#  {'symbol': 'XTZUSD',
#   'priceChange': '0.0423',
#   'priceChangePercent': '0.764',
#   'weightedAvgPrice': '5.4694',
#   'prevClosePrice': '5.5217',
#   'lastPrice': '5.5754',
#   'lastQty': '1.82000000',
#   'bidPrice': '5.5578',
#   'bidQty': '102.90000000',
#   'askPrice': '5.5692',
#   'askQty': '96.73000000',
#   'openPrice': '5.5331',
#   'highPrice': '5.8423',
#   'lowPrice': '5.1632',
#   'volume': '428356.97000000',
#   'quoteVolume': '2342838.1754',
#   'openTime': 1619014210248,
#   'closeTime': 1619100610248,
#   'firstId': 669687,
#   'lastId': 674390,
#   'count': 4704},
#  {'symbol': 'XTZBUSD',
#   'priceChange': '0.03810000',
#   'priceChangePercent': '0.689',
#   'weightedAvgPrice': '5.46806778',
#   'prevClosePrice': '5.52140000',
#   'lastPrice': '5.56730000',
#   'lastQty': '116.51000000',
#   'bidPrice': '5.54750000',
#   'bidQty': '359.40000000',
#   'askPrice': '5.57300000',
#   'askQty': '100.32000000',
#   'openPrice': '5.52920000',
#   'highPrice': '5.84210000',
#   'lowPrice': '5.17190000',
#   'volume': '74691.37000000',
#   'quoteVolume': '408417.47411200',
#   'openTime': 1619014209977,
#   'closeTime': 1619100609977,
#   'firstId': 91391,
#   'lastId': 92100,
#   'count': 710},
#  {'symbol': 'HBARUSD',
#   'priceChange': '-0.0063',
#   'priceChangePercent': '-2.075',
#   'weightedAvgPrice': '0.2979',
#   'prevClosePrice': '0.3035',
#   'lastPrice': '0.2973',
#   'lastQty': '188.00000000',
#   'bidPrice': '0.2973',
#   'bidQty': '98.50000000',
#   'askPrice': '0.2974',
#   'askQty': '16921.70000000',
#   'openPrice': '0.3036',
#   'highPrice': '0.3161',
#   'lowPrice': '0.2780',
#   'volume': '24090327.30000000',
#   'quoteVolume': '7176669.3105',
#   'openTime': 1619014211695,
#   'closeTime': 1619100611695,
#   'firstId': 1141321,
#   'lastId': 1153105,
#   'count': 11785},
#  {'symbol': 'HBARBUSD',
#   'priceChange': '-0.00728000',
#   'priceChangePercent': '-2.404',
#   'weightedAvgPrice': '0.29823722',
#   'prevClosePrice': '0.30332000',
#   'lastPrice': '0.29556000',
#   'lastQty': '3000.00000000',
#   'bidPrice': '0.29673000',
#   'bidQty': '5048.70000000',
#   'askPrice': '0.29727000',
#   'askQty': '3186.40000000',
#   'openPrice': '0.30284000',
#   'highPrice': '0.31556000',
#   'lowPrice': '0.27808000',
#   'volume': '2201336.20000000',
#   'quoteVolume': '656520.39662500',
#   'openTime': 1619014204233,
#   'closeTime': 1619100604233,
#   'firstId': 111416,
#   'lastId': 112316,
#   'count': 901},
#  {'symbol': 'OMGUSD',
#   'priceChange': '0.0478',
#   'priceChangePercent': '0.612',
#   'weightedAvgPrice': '7.8412',
#   'prevClosePrice': '7.8160',
#   'lastPrice': '7.8520',
#   'lastQty': '5.76000000',
#   'bidPrice': '7.8368',
#   'bidQty': '50.00000000',
#   'askPrice': '7.8524',
#   'askQty': '319.40000000',
#   'openPrice': '7.8042',
#   'highPrice': '8.4486',
#   'lowPrice': '7.3302',
#   'volume': '241313.96000000',
#   'quoteVolume': '1892193.3277',
#   'openTime': 1619014210493,
#   'closeTime': 1619100610493,
#   'firstId': 667447,
#   'lastId': 671545,
#   'count': 4099},
#  {'symbol': 'OMGBUSD',
#   'priceChange': '0.05560000',
#   'priceChangePercent': '0.714',
#   'weightedAvgPrice': '7.79409703',
#   'prevClosePrice': '7.81550000',
#   'lastPrice': '7.83930000',
#   'lastQty': '267.20000000',
#   'bidPrice': '7.83700000',
#   'bidQty': '82.07000000',
#   'askPrice': '7.85760000',
#   'askQty': '304.87000000',
#   'openPrice': '7.78370000',
#   'highPrice': '8.45700000',
#   'lowPrice': '7.37180000',
#   'volume': '65489.11000000',
#   'quoteVolume': '510428.47806000',
#   'openTime': 1619014209714,
#   'closeTime': 1619100609714,
#   'firstId': 123498,
#   'lastId': 124234,
#   'count': 737},
#  {'symbol': 'MATICUSD',
#   'priceChange': '0.0638',
#   'priceChangePercent': '18.547',
#   'weightedAvgPrice': '0.3886',
#   'prevClosePrice': '0.3440',
#   'lastPrice': '0.4078',
#   'lastQty': '394.70000000',
#   'bidPrice': '0.4079',
#   'bidQty': '11812.10000000',
#   'askPrice': '0.4087',
#   'askQty': '4900.10000000',
#   'openPrice': '0.3440',
#   'highPrice': '0.4182',
#   'lowPrice': '0.3413',
#   'volume': '53237671.30000000',
#   'quoteVolume': '20685780.9632',
#   'openTime': 1619014211719,
#   'closeTime': 1619100611719,
#   'firstId': 1068631,
#   'lastId': 1092966,
#   'count': 24336},
#  {'symbol': 'MATICBUSD',
#   'priceChange': '0.06418000',
#   'priceChangePercent': '18.667',
#   'weightedAvgPrice': '0.38838808',
#   'prevClosePrice': '0.34494000',
#   'lastPrice': '0.40799000',
#   'lastQty': '2322.40000000',
#   'bidPrice': '0.40778000',
#   'bidQty': '4901.10000000',
#   'askPrice': '0.40904000',
#   'askQty': '6435.60000000',
#   'openPrice': '0.34381000',
#   'highPrice': '0.41831000',
#   'lowPrice': '0.34313000',
#   'volume': '4248613.20000000',
#   'quoteVolume': '1650110.71812400',
#   'openTime': 1619014204778,
#   'closeTime': 1619100604778,
#   'firstId': 128413,
#   'lastId': 131328,
#   'count': 2916},
#  {'symbol': 'XTZBTC',
#   'priceChange': '0.00000230',
#   'priceChangePercent': '2.312',
#   'weightedAvgPrice': '0.00010138',
#   'prevClosePrice': '0.00009950',
#   'lastPrice': '0.00010180',
#   'lastQty': '51.96000000',
#   'bidPrice': '0.00010170',
#   'bidQty': '155.07000000',
#   'askPrice': '0.00010200',
#   'askQty': '201.98000000',
#   'openPrice': '0.00009950',
#   'highPrice': '0.00010510',
#   'lowPrice': '0.00009670',
#   'volume': '79647.02000000',
#   'quoteVolume': '8.07497311',
#   'openTime': 1619014204851,
#   'closeTime': 1619100604851,
#   'firstId': 233172,
#   'lastId': 234592,
#   'count': 1421},
#  {'symbol': 'ADABTC',
#   'priceChange': '0.00000005',
#   'priceChangePercent': '0.223',
#   'weightedAvgPrice': '0.00002242',
#   'prevClosePrice': '0.00002244',
#   'lastPrice': '0.00002246',
#   'lastQty': '415.00000000',
#   'bidPrice': '0.00002245',
#   'bidQty': '2443.00000000',
#   'askPrice': '0.00002247',
#   'askQty': '171.00000000',
#   'openPrice': '0.00002241',
#   'highPrice': '0.00002281',
#   'lowPrice': '0.00002208',
#   'volume': '3924797.00000000',
#   'quoteVolume': '87.98884083',
#   'openTime': 1619014207483,
#   'closeTime': 1619100607483,
#   'firstId': 844243,
#   'lastId': 848430,
#   'count': 4188},
#  {'symbol': 'REPBUSD',
#   'priceChange': '-1.75000000',
#   'priceChangePercent': '-4.513',
#   'weightedAvgPrice': '36.93300815',
#   'prevClosePrice': '39.04000000',
#   'lastPrice': '37.03000000',
#   'lastQty': '4.72000000',
#   'bidPrice': '37.05000000',
#   'bidQty': '6.17000000',
#   'askPrice': '37.23000000',
#   'askQty': '4.95400000',
#   'openPrice': '38.78000000',
#   'highPrice': '39.94000000',
#   'lowPrice': '35.17000000',
#   'volume': '1064.05800000',
#   'quoteVolume': '39298.86279000',
#   'openTime': 1619014204962,
#   'closeTime': 1619100604962,
#   'firstId': 56376,
#   'lastId': 56635,
#   'count': 260},
#  {'symbol': 'REPUSD',
#   'priceChange': '-2.0400',
#   'priceChangePercent': '-5.209',
#   'weightedAvgPrice': '37.0401',
#   'prevClosePrice': '39.2600',
#   'lastPrice': '37.1200',
#   'lastQty': '0.04800000',
#   'bidPrice': '37.0600',
#   'bidQty': '0.00100000',
#   'askPrice': '37.2000',
#   'askQty': '8.05300000',
#   'openPrice': '39.1600',
#   'highPrice': '40.0000',
#   'lowPrice': '34.8200',
#   'volume': '14035.66200000',
#   'quoteVolume': '519882.8133',
#   'openTime': 1619014179538,
#   'closeTime': 1619100579538,
#   'firstId': 298278,
#   'lastId': 300663,
#   'count': 2386},
#  {'symbol': 'EOSBUSD',
#   'priceChange': '0.04810000',
#   'priceChangePercent': '0.739',
#   'weightedAvgPrice': '6.41893427',
#   'prevClosePrice': '6.50160000',
#   'lastPrice': '6.55750000',
#   'lastQty': '84.07000000',
#   'bidPrice': '6.60320000',
#   'bidQty': '61.28000000',
#   'askPrice': '6.61950000',
#   'askQty': '372.35000000',
#   'openPrice': '6.50940000',
#   'highPrice': '6.78980000',
#   'lowPrice': '6.15990000',
#   'volume': '46046.73000000',
#   'quoteVolume': '295570.93339500',
#   'openTime': 1619014209781,
#   'closeTime': 1619100609781,
#   'firstId': 107046,
#   'lastId': 107523,
#   'count': 478},
#  {'symbol': 'EOSUSD',
#   'priceChange': '0.1048',
#   'priceChangePercent': '1.611',
#   'weightedAvgPrice': '6.4294',
#   'prevClosePrice': '6.5155',
#   'lastPrice': '6.6082',
#   'lastQty': '1.67000000',
#   'bidPrice': '6.6015',
#   'bidQty': '93.26000000',
#   'askPrice': '6.6115',
#   'askQty': '144.46000000',
#   'openPrice': '6.5034',
#   'highPrice': '6.7971',
#   'lowPrice': '6.1526',
#   'volume': '412854.70000000',
#   'quoteVolume': '2654418.4979',
#   'openTime': 1619014210461,
#   'closeTime': 1619100610461,
#   'firstId': 550911,
#   'lastId': 554573,
#   'count': 3663},
#  {'symbol': 'DOGEUSD',
#   'priceChange': '-0.0308',
#   'priceChangePercent': '-9.821',
#   'weightedAvgPrice': '0.2938',
#   'prevClosePrice': '0.3135',
#   'lastPrice': '0.2828',
#   'lastQty': '1169.00000000',
#   'bidPrice': '0.2825',
#   'bidQty': '1163.00000000',
#   'askPrice': '0.2827',
#   'askQty': '5161.00000000',
#   'openPrice': '0.3136',
#   'highPrice': '0.3352',
#   'lowPrice': '0.2560',
#   'volume': '584469568.00000000',
#   'quoteVolume': '171693148.7250',
#   'openTime': 1619014211144,
#   'closeTime': 1619100611144,
#   'firstId': 5571628,
#   'lastId': 5718648,
#   'count': 147021},
#  {'symbol': 'KNCUSD',
#   'priceChange': '-0.2890',
#   'priceChangePercent': '-8.816',
#   'weightedAvgPrice': '3.1655',
#   'prevClosePrice': '3.2780',
#   'lastPrice': '2.9890',
#   'lastQty': '233.61500000',
#   'bidPrice': '3.0010',
#   'bidQty': '784.21400000',
#   'askPrice': '3.0130',
#   'askQty': '680.58800000',
#   'openPrice': '3.2780',
#   'highPrice': '3.4200',
#   'lowPrice': '2.8470',
#   'volume': '303780.27700000',
#   'quoteVolume': '961610.3683',
#   'openTime': 1619014211137,
#   'closeTime': 1619100611137,
#   'firstId': 302819,
#   'lastId': 305836,
#   'count': 3018},
#  {'symbol': 'KNCUSDT',
#   'priceChange': '-0.31200000',
#   'priceChangePercent': '-9.463',
#   'weightedAvgPrice': '3.13804983',
#   'prevClosePrice': '3.28000000',
#   'lastPrice': '2.98500000',
#   'lastQty': '213.66400000',
#   'bidPrice': '3.00100000',
#   'bidQty': '664.73200000',
#   'askPrice': '3.01100000',
#   'askQty': '524.14500000',
#   'openPrice': '3.29700000',
#   'highPrice': '3.41200000',
#   'lowPrice': '2.84800000',
#   'volume': '183209.48500000',
#   'quoteVolume': '574920.49279600',
#   'openTime': 1619014210111,
#   'closeTime': 1619100610111,
#   'firstId': 142740,
#   'lastId': 144663,
#   'count': 1924},
#  {'symbol': 'VTHOUSDT',
#   'priceChange': '-0.00171500',
#   'priceChangePercent': '-8.223',
#   'weightedAvgPrice': '0.01977469',
#   'prevClosePrice': '0.02085000',
#   'lastPrice': '0.01914100',
#   'lastQty': '8742.00000000',
#   'bidPrice': '0.01918500',
#   'bidQty': '113727.00000000',
#   'askPrice': '0.01920400',
#   'askQty': '315.00000000',
#   'openPrice': '0.02085600',
#   'highPrice': '0.02109500',
#   'lowPrice': '0.01868300',
#   'volume': '176366411.00000000',
#   'quoteVolume': '3487590.86328500',
#   'openTime': 1619014196472,
#   'closeTime': 1619100596472,
#   'firstId': 852049,
#   'lastId': 857878,
#   'count': 5830},
#  {'symbol': 'VTHOUSD',
#   'priceChange': '-0.0017',
#   'priceChangePercent': '-8.095',
#   'weightedAvgPrice': '0.0199',
#   'prevClosePrice': '0.0209',
#   'lastPrice': '0.0193',
#   'lastQty': '11639.00000000',
#   'bidPrice': '0.0192',
#   'bidQty': '7080846.00000000',
#   'askPrice': '0.0193',
#   'askQty': '397112.00000000',
#   'openPrice': '0.0210',
#   'highPrice': '0.0212',
#   'lowPrice': '0.0187',
#   'volume': '997544286.00000000',
#   'quoteVolume': '19808720.5928',
#   'openTime': 1619014210579,
#   'closeTime': 1619100610579,
#   'firstId': 2234625,
#   'lastId': 2270036,
#   'count': 35412},
#  {'symbol': 'USDCUSD',
#   'priceChange': '-0.0001',
#   'priceChangePercent': '-0.010',
#   'weightedAvgPrice': '0.9999',
#   'prevClosePrice': '1.0000',
#   'lastPrice': '0.9998',
#   'lastQty': '3092.48000000',
#   'bidPrice': '0.9998',
#   'bidQty': '84920.77000000',
#   'askPrice': '0.9999',
#   'askQty': '64823.31000000',
#   'openPrice': '0.9999',
#   'highPrice': '1.0007',
#   'lowPrice': '0.9992',
#   'volume': '3671639.52000000',
#   'quoteVolume': '3671293.4148',
#   'openTime': 1619014147959,
#   'closeTime': 1619100547959,
#   'firstId': 109493,
#   'lastId': 110442,
#   'count': 950},
#  {'symbol': 'COMPUSDT',
#   'priceChange': '95.70000000',
#   'priceChangePercent': '20.338',
#   'weightedAvgPrice': '539.51467391',
#   'prevClosePrice': '470.66000000',
#   'lastPrice': '566.25000000',
#   'lastQty': '0.13562000',
#   'bidPrice': '567.57000000',
#   'bidQty': '0.73588000',
#   'askPrice': '569.01000000',
#   'askQty': '3.51928000',
#   'openPrice': '470.55000000',
#   'highPrice': '600.24000000',
#   'lowPrice': '466.79000000',
#   'volume': '2226.47180000',
#   'quoteVolume': '1201214.20713930',
#   'openTime': 1619014210041,
#   'closeTime': 1619100610041,
#   'firstId': 218746,
#   'lastId': 222728,
#   'count': 3983},
#  {'symbol': 'COMPUSD',
#   'priceChange': '92.7900',
#   'priceChangePercent': '19.654',
#   'weightedAvgPrice': '538.7478',
#   'prevClosePrice': '472.1100',
#   'lastPrice': '564.9000',
#   'lastQty': '0.47459000',
#   'bidPrice': '567.5000',
#   'bidQty': '2.19779000',
#   'askPrice': '569.0200',
#   'askQty': '3.06303000',
#   'openPrice': '472.1100',
#   'highPrice': '596.0000',
#   'lowPrice': '467.3200',
#   'volume': '6053.29471000',
#   'quoteVolume': '3261199.0962',
#   'openTime': 1619014210513,
#   'closeTime': 1619100610513,
#   'firstId': 391451,
#   'lastId': 398984,
#   'count': 7534},
#  {'symbol': 'MANAUSD',
#   'priceChange': '0.0251',
#   'priceChangePercent': '1.859',
#   'weightedAvgPrice': '1.3473',
#   'prevClosePrice': '1.3501',
#   'lastPrice': '1.3751',
#   'lastQty': '8.75000000',
#   'bidPrice': '1.3745',
#   'bidQty': '2134.77000000',
#   'askPrice': '1.3764',
#   'askQty': '30.56000000',
#   'openPrice': '1.3500',
#   'highPrice': '1.4316',
#   'lowPrice': '1.2705',
#   'volume': '4795301.44000000',
#   'quoteVolume': '6460626.5733',
#   'openTime': 1619014195044,
#   'closeTime': 1619100595044,
#   'firstId': 1080034,
#   'lastId': 1093332,
#   'count': 13299},
#  {'symbol': 'HNTUSD',
#   'priceChange': '1.0081',
#   'priceChangePercent': '8.213',
#   'weightedAvgPrice': '12.8888',
#   'prevClosePrice': '12.2029',
#   'lastPrice': '13.2826',
#   'lastQty': '22.78000000',
#   'bidPrice': '13.2153',
#   'bidQty': '128.83000000',
#   'askPrice': '13.2826',
#   'askQty': '233.69000000',
#   'openPrice': '12.2745',
#   'highPrice': '13.8722',
#   'lowPrice': '12.0804',
#   'volume': '206250.67000000',
#   'quoteVolume': '2658332.8099',
#   'openTime': 1619014211639,
#   'closeTime': 1619100611639,
#   'firstId': 661533,
#   'lastId': 671400,
#   'count': 9868},
#  {'symbol': 'HNTUSDT',
#   'priceChange': '1.04040000',
#   'priceChangePercent': '8.525',
#   'weightedAvgPrice': '12.74075034',
#   'prevClosePrice': '12.27198000',
#   'lastPrice': '13.24419000',
#   'lastQty': '6.50000000',
#   'bidPrice': '13.23709000',
#   'bidQty': '6.00000000',
#   'askPrice': '13.25500000',
#   'askQty': '0.80000000',
#   'openPrice': '12.20379000',
#   'highPrice': '13.69111000',
#   'lowPrice': '12.09357000',
#   'volume': '75948.60000000',
#   'quoteVolume': '967642.15099200',
#   'openTime': 1619014211468,
#   'closeTime': 1619100611468,
#   'firstId': 309793,
#   'lastId': 313841,
#   'count': 4049},
#  {'symbol': 'MKRUSD',
#   'priceChange': '731.5595',
#   'priceChangePercent': '19.429',
#   'weightedAvgPrice': '4450.6624',
#   'prevClosePrice': '3765.7929',
#   'lastPrice': '4496.8430',
#   'lastQty': '0.00512000',
#   'bidPrice': '4477.5936',
#   'bidQty': '0.22122000',
#   'askPrice': '4496.8431',
#   'askQty': '0.14232000',
#   'openPrice': '3765.2835',
#   'highPrice': '4995.0000',
#   'lowPrice': '3707.1739',
#   'volume': '3160.30150000',
#   'quoteVolume': '14065434.9659',
#   'openTime': 1619014211720,
#   'closeTime': 1619100611720,
#   'firstId': 297890,
#   'lastId': 320725,
#   'count': 22836},
#  {'symbol': 'MKRUSDT',
#   'priceChange': '726.66000000',
#   'priceChangePercent': '19.342',
#   'weightedAvgPrice': '4402.57197432',
#   'prevClosePrice': '3762.20000000',
#   'lastPrice': '4483.65000000',
#   'lastQty': '0.23703000',
#   'bidPrice': '4473.63000000',
#   'bidQty': '0.44625000',
#   'askPrice': '4487.34000000',
#   'askQty': '0.22338000',
#   'openPrice': '3756.99000000',
#   'highPrice': '4990.00000000',
#   'lowPrice': '3714.72000000',
#   'volume': '1436.16539000',
#   'quoteVolume': '6322821.49649600',
#   'openTime': 1619014211661,
#   'closeTime': 1619100611661,
#   'firstId': 156578,
#   'lastId': 168580,
#   'count': 12003},
#  {'symbol': 'DAIUSD',
#   'priceChange': '0.0005',
#   'priceChangePercent': '0.050',
#   'weightedAvgPrice': '1.0001',
#   'prevClosePrice': '1.0004',
#   'lastPrice': '1.0009',
#   'lastQty': '805.43000000',
#   'bidPrice': '1.0003',
#   'bidQty': '37301.75000000',
#   'askPrice': '1.0009',
#   'askQty': '33372.16000000',
#   'openPrice': '1.0004',
#   'highPrice': '1.0013',
#   'lowPrice': '0.9993',
#   'volume': '1274292.79000000',
#   'quoteVolume': '1274391.8948',
#   'openTime': 1619014118813,
#   'closeTime': 1619100518813,
#   'firstId': 38718,
#   'lastId': 39156,
#   'count': 439},
#  {'symbol': 'ONEUSDT',
#   'priceChange': '-0.00112000',
#   'priceChangePercent': '-0.934',
#   'weightedAvgPrice': '0.11854536',
#   'prevClosePrice': '0.11997000',
#   'lastPrice': '0.11874000',
#   'lastQty': '6878.40000000',
#   'bidPrice': '0.11880000',
#   'bidQty': '16812.10000000',
#   'askPrice': '0.11912000',
#   'askQty': '48503.40000000',
#   'openPrice': '0.11986000',
#   'highPrice': '0.12527000',
#   'lowPrice': '0.11041000',
#   'volume': '39869340.10000000',
#   'quoteVolume': '4726325.14772200',
#   'openTime': 1619014209265,
#   'closeTime': 1619100609265,
#   'firstId': 871642,
#   'lastId': 876220,
#   'count': 4579},
#  {'symbol': 'ONEUSD',
#   'priceChange': '-0.0010',
#   'priceChangePercent': '-0.832',
#   'weightedAvgPrice': '0.1188',
#   'prevClosePrice': '0.1202',
#   'lastPrice': '0.1192',
#   'lastQty': '828.70000000',
#   'bidPrice': '0.1188',
#   'bidQty': '15857.70000000',
#   'askPrice': '0.1192',
#   'askQty': '78583.30000000',
#   'openPrice': '0.1202',
#   'highPrice': '0.1250',
#   'lowPrice': '0.1100',
#   'volume': '163585697.10000000',
#   'quoteVolume': '19434402.7018',
#   'openTime': 1619014211548,
#   'closeTime': 1619100611548,
#   'firstId': 2727670,
#   'lastId': 2752980,
#   'count': 25311},
#  {'symbol': 'BANDUSDT',
#   'priceChange': '1.55470000',
#   'priceChangePercent': '9.265',
#   'weightedAvgPrice': '16.83417764',
#   'prevClosePrice': '16.76250000',
#   'lastPrice': '18.33450000',
#   'lastQty': '0.82000000',
#   'bidPrice': '18.29020000',
#   'bidQty': '3.29000000',
#   'askPrice': '18.36360000',
#   'askQty': '18.90000000',
#   'openPrice': '16.77980000',
#   'highPrice': '18.60000000',
#   'lowPrice': '15.58020000',
#   'volume': '93263.10000000',
#   'quoteVolume': '1570007.59296800',
#   'openTime': 1619014210861,
#   'closeTime': 1619100610861,
#   'firstId': 225178,
#   'lastId': 228393,
#   'count': 3216},
#  {'symbol': 'BANDUSD',
#   'priceChange': '1.5736',
#   'priceChangePercent': '9.370',
#   'weightedAvgPrice': '16.8275',
#   'prevClosePrice': '16.8263',
#   'lastPrice': '18.3673',
#   'lastQty': '3.61000000',
#   'bidPrice': '18.3034',
#   'bidQty': '400.00000000',
#   'askPrice': '18.3673',
#   'askQty': '16.87000000',
#   'openPrice': '16.7937',
#   'highPrice': '18.5726',
#   'lowPrice': '15.5374',
#   'volume': '164563.31000000',
#   'quoteVolume': '2769192.4273',
#   'openTime': 1619014211642,
#   'closeTime': 1619100611642,
#   'firstId': 411986,
#   'lastId': 418480,
#   'count': 6495},
#  {'symbol': 'STORJUSDT',
#   'priceChange': '-0.13630000',
#   'priceChangePercent': '-6.979',
#   'weightedAvgPrice': '1.87792060',
#   'prevClosePrice': '1.95320000',
#   'lastPrice': '1.81680000',
#   'lastQty': '40.40000000',
#   'bidPrice': '1.83700000',
#   'bidQty': '1087.58000000',
#   'askPrice': '1.83970000',
#   'askQty': '1087.24000000',
#   'openPrice': '1.95310000',
#   'highPrice': '1.99920000',
#   'lowPrice': '1.75380000',
#   'volume': '656343.25000000',
#   'quoteVolume': '1232560.50683700',
#   'openTime': 1619014207320,
#   'closeTime': 1619100607320,
#   'firstId': 311351,
#   'lastId': 313307,
#   'count': 1957},
#  {'symbol': 'STORJUSD',
#   'priceChange': '-0.1158',
#   'priceChangePercent': '-5.928',
#   'weightedAvgPrice': '1.8681',
#   'prevClosePrice': '1.9548',
#   'lastPrice': '1.8377',
#   'lastQty': '9.43000000',
#   'bidPrice': '1.8378',
#   'bidQty': '1087.46000000',
#   'askPrice': '1.8402',
#   'askQty': '1087.82000000',
#   'openPrice': '1.9535',
#   'highPrice': '1.9987',
#   'lowPrice': '1.7513',
#   'volume': '1985550.65000000',
#   'quoteVolume': '3709283.8614',
#   'openTime': 1619014205143,
#   'closeTime': 1619100605143,
#   'firstId': 850943,
#   'lastId': 856765,
#   'count': 5823},
#  {'symbol': 'BUSDUSDT',
#   'priceChange': '0.00030000',
#   'priceChangePercent': '0.030',
#   'weightedAvgPrice': '0.99949292',
#   'prevClosePrice': '0.99920000',
#   'lastPrice': '0.99950000',
#   'lastQty': '3156.44000000',
#   'bidPrice': '0.99940000',
#   'bidQty': '10000.00000000',
#   'askPrice': '0.99950000',
#   'askQty': '300269.48000000',
#   'openPrice': '0.99920000',
#   'highPrice': '1.00000000',
#   'lowPrice': '0.99920000',
#   'volume': '1023609.65000000',
#   'quoteVolume': '1023090.60298600',
#   'openTime': 1619014129942,
#   'closeTime': 1619100529942,
#   'firstId': 62409,
#   'lastId': 62827,
#   'count': 419},
#  {'symbol': 'UNIUSD',
#   'priceChange': '4.4918',
#   'priceChangePercent': '13.849',
#   'weightedAvgPrice': '35.6882',
#   'prevClosePrice': '32.4675',
#   'lastPrice': '36.9266',
#   'lastQty': '0.53000000',
#   'bidPrice': '36.8457',
#   'bidQty': '0.53000000',
#   'askPrice': '36.8897',
#   'askQty': '0.28000000',
#   'openPrice': '32.4348',
#   'highPrice': '38.4000',
#   'lowPrice': '31.8571',
#   'volume': '344554.84000000',
#   'quoteVolume': '12296536.2693',
#   'openTime': 1619014211512,
#   'closeTime': 1619100611512,
#   'firstId': 927905,
#   'lastId': 949968,
#   'count': 22064},
#  {'symbol': 'UNIUSDT',
#   'priceChange': '4.43000000',
#   'priceChangePercent': '13.640',
#   'weightedAvgPrice': '35.64704111',
#   'prevClosePrice': '32.41720000',
#   'lastPrice': '36.90750000',
#   'lastQty': '2.17000000',
#   'bidPrice': '36.82120000',
#   'bidQty': '37.90000000',
#   'askPrice': '36.85460000',
#   'askQty': '34.43000000',
#   'openPrice': '32.47750000',
#   'highPrice': '38.44780000',
#   'lowPrice': '31.86840000',
#   'volume': '241044.22000000',
#   'quoteVolume': '8592513.21944600',
#   'openTime': 1619014211062,
#   'closeTime': 1619100611062,
#   'firstId': 482249,
#   'lastId': 493864,
#   'count': 11616},
#  {'symbol': 'SOLUSD',
#   'priceChange': '3.4442',
#   'priceChangePercent': '10.254',
#   'weightedAvgPrice': '34.9039',
#   'prevClosePrice': '33.4669',
#   'lastPrice': '37.0324',
#   'lastQty': '4.07000000',
#   'bidPrice': '36.9604',
#   'bidQty': '55.51000000',
#   'askPrice': '37.0324',
#   'askQty': '49.99000000',
#   'openPrice': '33.5882',
#   'highPrice': '37.8999',
#   'lowPrice': '31.5122',
#   'volume': '610752.98000000',
#   'quoteVolume': '21317688.8735',
#   'openTime': 1619014210297,
#   'closeTime': 1619100610297,
#   'firstId': 611111,
#   'lastId': 632593,
#   'count': 21483},
#  {'symbol': 'SOLUSDT',
#   'priceChange': '3.48840000',
#   'priceChangePercent': '10.400',
#   'weightedAvgPrice': '34.72181006',
#   'prevClosePrice': '33.52290000',
#   'lastPrice': '37.03160000',
#   'lastQty': '1.34000000',
#   'bidPrice': '36.94050000',
#   'bidQty': '63.30000000',
#   'askPrice': '37.01770000',
#   'askQty': '54.07000000',
#   'openPrice': '33.54320000',
#   'highPrice': '38.67630000',
#   'lowPrice': '31.46420000',
#   'volume': '390525.67000000',
#   'quoteVolume': '13559758.13659900',
#   'openTime': 1619014210303,
#   'closeTime': 1619100610303,
#   'firstId': 297759,
#   'lastId': 310467,
#   'count': 12709},
#  {'symbol': 'LINKBTC',
#   'priceChange': '0.00004912',
#   'priceChangePercent': '7.262',
#   'weightedAvgPrice': '0.00068981',
#   'prevClosePrice': '0.00067607',
#   'lastPrice': '0.00072551',
#   'lastQty': '8.30000000',
#   'bidPrice': '0.00072410',
#   'bidQty': '104.10000000',
#   'askPrice': '0.00072551',
#   'askQty': '42.20000000',
#   'openPrice': '0.00067639',
#   'highPrice': '0.00072552',
#   'lowPrice': '0.00066885',
#   'volume': '81602.30000000',
#   'quoteVolume': '56.29015719',
#   'openTime': 1619014211465,
#   'closeTime': 1619100611465,
#   'firstId': 392564,
#   'lastId': 396451,
#   'count': 3888},
#  {'symbol': 'VETBTC',
#   'priceChange': '-0.00000021',
#   'priceChangePercent': '-4.872',
#   'weightedAvgPrice': '0.00000417',
#   'prevClosePrice': '0.00000430',
#   'lastPrice': '0.00000410',
#   'lastQty': '6573.00000000',
#   'bidPrice': '0.00000409',
#   'bidQty': '30055.00000000',
#   'askPrice': '0.00000410',
#   'askQty': '7873.00000000',
#   'openPrice': '0.00000431',
#   'highPrice': '0.00000436',
#   'lowPrice': '0.00000389',
#   'volume': '49550734.00000000',
#   'quoteVolume': '206.51277595',
#   'openTime': 1619014211597,
#   'closeTime': 1619100611597,
#   'firstId': 630433,
#   'lastId': 646487,
#   'count': 16055},
#  {'symbol': 'UNIBTC',
#   'priceChange': '0.00008971',
#   'priceChangePercent': '15.333',
#   'weightedAvgPrice': '0.00064900',
#   'prevClosePrice': '0.00058339',
#   'lastPrice': '0.00067478',
#   'lastQty': '3.00000000',
#   'bidPrice': '0.00067396',
#   'bidQty': '163.00000000',
#   'askPrice': '0.00067528',
#   'askQty': '50.00000000',
#   'openPrice': '0.00058507',
#   'highPrice': '0.00071230',
#   'lowPrice': '0.00057820',
#   'volume': '230493.00000000',
#   'quoteVolume': '149.59028064',
#   'openTime': 1619014211202,
#   'closeTime': 1619100611202,
#   'firstId': 198764,
#   'lastId': 205571,
#   'count': 6808},
#  {'symbol': 'EGLDUSDT',
#   'priceChange': '-1.51000000',
#   'priceChangePercent': '-0.816',
#   'weightedAvgPrice': '184.44125192',
#   'prevClosePrice': '185.12500000',
#   'lastPrice': '183.61500000',
#   'lastQty': '0.18500000',
#   'bidPrice': '183.41700000',
#   'bidQty': '8.15900000',
#   'askPrice': '183.61500000',
#   'askQty': '1.62900000',
#   'openPrice': '185.12500000',
#   'highPrice': '195.69400000',
#   'lowPrice': '175.00900000',
#   'volume': '31380.64700000',
#   'quoteVolume': '5787885.81863100',
#   'openTime': 1619014209940,
#   'closeTime': 1619100609940,
#   'firstId': 663530,
#   'lastId': 672720,
#   'count': 9191},
#  {'symbol': 'EGLDUSD',
#   'priceChange': '-1.6790',
#   'priceChangePercent': '-0.906',
#   'weightedAvgPrice': '184.9604',
#   'prevClosePrice': '185.2730',
#   'lastPrice': '183.6370',
#   'lastQty': '2.11400000',
#   'bidPrice': '183.3870',
#   'bidQty': '8.16400000',
#   'askPrice': '183.6620',
#   'askQty': '1.72400000',
#   'openPrice': '185.3160',
#   'highPrice': '196.1250',
#   'lowPrice': '174.7550',
#   'volume': '27423.51400000',
#   'quoteVolume': '5072263.5517',
#   'openTime': 1619014209941,
#   'closeTime': 1619100609941,
#   'firstId': 919227,
#   'lastId': 930212,
#   'count': 10986},
#  {'symbol': 'PAXGUSDT',
#   'priceChange': '-11.47000000',
#   'priceChangePercent': '-0.635',
#   'weightedAvgPrice': '1810.56319256',
#   'prevClosePrice': '1806.86000000',
#   'lastPrice': '1795.39000000',
#   'lastQty': '0.27849100',
#   'bidPrice': '1789.43000000',
#   'bidQty': '0.31651900',
#   'askPrice': '1795.39000000',
#   'askQty': '5.05097000',
#   'openPrice': '1806.86000000',
#   'highPrice': '1815.41000000',
#   'lowPrice': '1787.92000000',
#   'volume': '29.21506800',
#   'quoteVolume': '52895.72678902',
#   'openTime': 1619014190970,
#   'closeTime': 1619100590970,
#   'firstId': 15154,
#   'lastId': 15330,
#   'count': 177},
#  {'symbol': 'PAXGUSD',
#   'priceChange': '-7.3500',
#   'priceChangePercent': '-0.407',
#   'weightedAvgPrice': '1809.8278',
#   'prevClosePrice': '1803.2400',
#   'lastPrice': '1797.1700',
#   'lastQty': '0.26619800',
#   'bidPrice': '1796.5700',
#   'bidQty': '0.03626200',
#   'askPrice': '1797.0500',
#   'askQty': '0.03926500',
#   'openPrice': '1804.5200',
#   'highPrice': '1831.8100',
#   'lowPrice': '1790.5000',
#   'volume': '79.66624800',
#   'quoteVolume': '144182.1906',
#   'openTime': 1619014207655,
#   'closeTime': 1619100607655,
#   'firstId': 36233,
#   'lastId': 36937,
#   'count': 705},
#  {'symbol': 'OXTUSDT',
#   'priceChange': '-0.02150000',
#   'priceChangePercent': '-3.207',
#   'weightedAvgPrice': '0.65280561',
#   'prevClosePrice': '0.67550000',
#   'lastPrice': '0.64890000',
#   'lastQty': '2308.45000000',
#   'bidPrice': '0.65080000',
#   'bidQty': '3068.19000000',
#   'askPrice': '0.65210000',
#   'askQty': '3068.42000000',
#   'openPrice': '0.67040000',
#   'highPrice': '0.69750000',
#   'lowPrice': '0.61090000',
#   'volume': '926412.34000000',
#   'quoteVolume': '604767.17617400',
#   'openTime': 1619014191964,
#   'closeTime': 1619100591964,
#   'firstId': 166947,
#   'lastId': 167788,
#   'count': 842},
#  {'symbol': 'OXTUSD',
#   'priceChange': '-0.0245',
#   'priceChangePercent': '-3.632',
#   'weightedAvgPrice': '0.6493',
#   'prevClosePrice': '0.6742',
#   'lastPrice': '0.6501',
#   'lastQty': '1786.88000000',
#   'bidPrice': '0.6510',
#   'bidQty': '3068.19000000',
#   'askPrice': '0.6524',
#   'askQty': '3068.01000000',
#   'openPrice': '0.6746',
#   'highPrice': '0.6981',
#   'lowPrice': '0.6101',
#   'volume': '2309012.14000000',
#   'quoteVolume': '1499153.3123',
#   'openTime': 1619014192033,
#   'closeTime': 1619100592033,
#   'firstId': 391587,
#   'lastId': 394949,
#   'count': 3363},
#  {'symbol': 'ZENUSDT',
#   'priceChange': '0.39900000',
#   'priceChangePercent': '0.345',
#   'weightedAvgPrice': '113.18528772',
#   'prevClosePrice': '115.32200000',
#   'lastPrice': '115.89200000',
#   'lastQty': '0.18500000',
#   'bidPrice': '115.79600000',
#   'bidQty': '11.50600000',
#   'askPrice': '116.12800000',
#   'askQty': '46.62300000',
#   'openPrice': '115.49300000',
#   'highPrice': '120.84900000',
#   'lowPrice': '106.38400000',
#   'volume': '12749.05000000',
#   'quoteVolume': '1443004.89238200',
#   'openTime': 1619014209806,
#   'closeTime': 1619100609806,
#   'firstId': 180215,
#   'lastId': 183158,
#   'count': 2944},
#  {'symbol': 'ZENUSD',
#   'priceChange': '0.4340',
#   'priceChangePercent': '0.375',
#   'weightedAvgPrice': '113.1115',
#   'prevClosePrice': '115.0200',
#   'lastPrice': '116.0210',
#   'lastQty': '6.47000000',
#   'bidPrice': '115.8310',
#   'bidQty': '11.92000000',
#   'askPrice': '116.1110',
#   'askQty': '0.21500000',
#   'openPrice': '115.5870',
#   'highPrice': '120.9650',
#   'lowPrice': '106.1700',
#   'volume': '17659.43700000',
#   'quoteVolume': '1997485.2442',
#   'openTime': 1619014206266,
#   'closeTime': 1619100606266,
#   'firstId': 235912,
#   'lastId': 240978,
#   'count': 5067},
#  {'symbol': 'BTCUSDC',
#   'priceChange': '-824.02000000',
#   'priceChangePercent': '-1.486',
#   'weightedAvgPrice': '54172.76605843',
#   'prevClosePrice': '55670.74000000',
#   'lastPrice': '54638.18000000',
#   'lastQty': '0.00980000',
#   'bidPrice': '54606.37000000',
#   'bidQty': '0.09026500',
#   'askPrice': '54692.04000000',
#   'askQty': '0.10801800',
#   'openPrice': '55462.20000000',
#   'highPrice': '56340.38000000',
#   'lowPrice': '52556.11000000',
#   'volume': '41.53396200',
#   'quoteVolume': '2250009.60690554',
#   'openTime': 1619014211706,
#   'closeTime': 1619100611706,
#   'firstId': 95303,
#   'lastId': 96279,
#   'count': 977},
#  {'symbol': 'ONEBUSD',
#   'priceChange': '-0.00140700',
#   'priceChangePercent': '-1.173',
#   'weightedAvgPrice': '0.11824189',
#   'prevClosePrice': '0.12016000',
#   'lastPrice': '0.11849800',
#   'lastQty': '89.00000000',
#   'bidPrice': '0.11876700',
#   'bidQty': '42010.00000000',
#   'askPrice': '0.11917000',
#   'askQty': '42060.00000000',
#   'openPrice': '0.11990500',
#   'highPrice': '0.12523600',
#   'lowPrice': '0.11045000',
#   'volume': '4092955.00000000',
#   'quoteVolume': '483958.71450400',
#   'openTime': 1619014211597,
#   'closeTime': 1619100611597,
#   'firstId': 88658,
#   'lastId': 89403,
#   'count': 746}]

# %%
# not the easiest to read, so add it to a pandas DataFrame
tickers_df = pd.DataFrame(tickers)
tickers_df
# Out:
#       symbol    priceChange priceChangePercent weightedAvgPrice  \
# 0     BTCUSD      -852.6200             -1.536       54485.4689
# 1     ETHUSD       185.4200              7.778        2438.6539
# 2     XRPUSD         0.0000              0.000           0.2970
# 3     BCHUSD        -4.5800             -0.485         935.1071
# 4     LTCUSD        13.7900              5.209         268.9960
# ..       ...            ...                ...              ...
# 104   OXTUSD        -0.0245             -3.632           0.6493
# 105  ZENUSDT     0.39900000              0.345     113.18528772
# 106   ZENUSD         0.4340              0.375         113.1115
# 107  BTCUSDC  -824.02000000             -1.486   54172.76605843
# 108  ONEBUSD    -0.00140700             -1.173       0.11824189
#
#      prevClosePrice       lastPrice        lastQty        bidPrice  \
# 0        55525.4000      54672.7800     0.00837000      54663.3900
# 1         2383.8700       2569.4000     0.16947000       2569.5700
# 2            0.2970          0.2970  2180.60000000          0.0000
# 3          945.2900        939.8800     1.33669000        939.3200
# 4          264.3000        278.5300     1.00000000        278.1400
# ..              ...             ...            ...             ...
# 104          0.6742          0.6501  1786.88000000          0.6510
# 105    115.32200000    115.89200000     0.18500000    115.79600000
# 106        115.0200        116.0210     6.47000000        115.8310
# 107  55670.74000000  54638.18000000     0.00980000  54606.37000000
# 108      0.12016000      0.11849800    89.00000000      0.11876700
#
#              bidQty        askPrice  ...       openPrice       highPrice  \
# 0        0.00000500      54663.4000  ...      55525.4000      56379.9700
# 1        1.06579000       2570.7500  ...       2383.9800       2600.0000
# 2        0.00000000          0.0000  ...          0.2970          0.2970
# 3        0.84082000        940.7900  ...        944.4600        989.0600
# 4        0.79003000        278.5400  ...        264.7400        286.1800
# ..              ...             ...  ...             ...             ...
# 104   3068.19000000          0.6524  ...          0.6746          0.6981
# 105     11.50600000    116.12800000  ...    115.49300000    120.84900000
# 106     11.92000000        116.1110  ...        115.5870        120.9650
# 107      0.09026500  54692.04000000  ...  55462.20000000  56340.38000000
# 108  42010.00000000      0.11917000  ...      0.11990500      0.12523600
#
#            lowPrice            volume       quoteVolume       openTime  \
# 0        52600.0000     1720.35770200     93734496.1340  1619014209574
# 1         2316.1800    44523.33795000    108577013.9571  1619014211758
# 2            0.2970     2180.60000000          647.6382  1618492909016
# 3          886.0000     4818.80953000      4506103.1347  1619014211450
# 4          251.2800    50527.80283000     13591774.6350  1619014211105
# ..              ...               ...               ...            ...
# 104          0.6101  2309012.14000000      1499153.3123  1619014192033
# 105    106.38400000    12749.05000000  1443004.89238200  1619014209806
# 106        106.1700    17659.43700000      1997485.2442  1619014206266
# 107  52556.11000000       41.53396200  2250009.60690554  1619014211706
# 108      0.11045000  4092955.00000000   483958.71450400  1619014211597
#
#          closeTime   firstId    lastId   count
# 0    1619100609574  10861267  10952425   91159
# 1    1619100611758   4966647   5078606  111960
# 2    1618579309016   1603396   1603396       1
# 3    1619100611450   1079253   1091804   12552
# 4    1619100611105   1669042   1694084   25043
# ..             ...       ...       ...     ...
# 104  1619100592033    391587    394949    3363
# 105  1619100609806    180215    183158    2944
# 106  1619100606266    235912    240978    5067
# 107  1619100611706     95303     96279     977
# 108  1619100611597     88658     89403     746
#
# [109 rows x 21 columns]
